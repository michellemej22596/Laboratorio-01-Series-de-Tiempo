# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.tsa as tsa
import statsmodels as sm
from datetime import datetime
import os
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
import tensorflow as tf
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## La Serie

# %%
import pandas as pd
import tensorflow as tf
from datetime import datetime

tf.random.set_seed(123)

# Leer el archivo Excel y parsear la fecha
df = pd.read_excel("Datos Originales/Importacion.xlsx")
df["Fecha"] = pd.to_datetime(df["Fecha"])
df.set_index("Fecha", inplace=True)

serie = df[["Gasolina superior"]].dropna()

print('\n Datos parseados:')
serie.head()
# Out:
#  Datos parseados:
#             Gasolina superior
# Fecha
# 2001-01-01          373963.96
# 2001-02-01          243091.07
# 2001-03-01          312084.38
# 2001-04-01          285054.89
# 2001-05-01          300913.67

# %% [markdown]
# A continuación podemos ver el gráfico de la serie.

# %%
plt.plot(serie)
plt.gca().set(title="Importacion de gasolina superior por mes", xlabel="Año", ylabel="Galones")
plt.show()

# %% [markdown]
# (Como se puede ver la serie no es estacionaria en media y la LSTM funciona mejor con series estacionarizadas así que vamos a diferenciarla na vez a ver si es suficiente para estacionarizarla en media)

# %%
# Calcular media móvil y desviación estándar móvil de los últimos 12 meses
mediaMovil = serie.rolling(window=12).mean()
deMovil = serie.rolling(window=12).std()

# Graficar resultados
plt.plot(serie, color="blue", label="Original")
plt.plot(mediaMovil, color='red', label='Media Móvil')
plt.plot(deMovil, color='black', label='Desviación Estándar Móvil')
plt.legend(loc='best')
plt.title('Media y desviación estándar móvil - Gasolina superior')
plt.xlabel('Año')
plt.ylabel('Galones')
plt.show()

# %%
descomposicion = seasonal_decompose(serie)
descomposicion.plot()

# %% [markdown]
# En este gráfico se puede observar que hay tendencia por lo que la serie no parece ser estacionaria en media y tampoco en varianza.

# %%
from statsmodels.tsa.stattools import adfuller

print('Resultados del Test de Dickey-Fuller para Gasolina Superior')
dfTest = adfuller(serie["Gasolina superior"], autolag='AIC')
salidaDf = pd.Series(dfTest[0:4], index=[
    'Estadístico de prueba',
    'p-value',
    '# de retardos usados',
    '# de observaciones usadas'
])
for key, value in dfTest[4].items():
    salidaDf[f'Valor crítico ({key})'] = value

print(salidaDf)
# Out:
# Resultados del Test de Dickey-Fuller para Gasolina Superior
# Estadístico de prueba         -1.601987
# p-value                        0.482595
# # de retardos usados           9.000000
# # de observaciones usadas    278.000000
# Valor crítico (1%)            -3.454094
# Valor crítico (5%)            -2.871993
# Valor crítico (10%)           -2.572340
# dtype: float64

# %% [markdown]
# El p-value es mayor a 0.05 por lo que no se puede rechazar la hipótesis nula de que existen raices unitarias, es decir, tiene una tendencia o depende mucho de su valor pasado (no es estacionaria).
#
# Como la serie no es estacionaria en media, vamos a probar con una diferenciación

# %%
print('Resultados del Test de Dickey-Fuller para una diferenciación de la serie Gasolina Superior')

# Diferenciar la serie
serie_diff = serie["Gasolina superior"].diff()
serie_diff.fillna(0, inplace=True)

# Prueba de Dickey-Fuller sobre la serie diferenciada
dfTest = adfuller(serie_diff)
salidaDf = pd.Series(dfTest[0:4], index=[
    'Estadístico de prueba',
    'p-value',
    '# de retardos usados',
    '# de observaciones usadas'
])
for key, value in dfTest[4].items():
    salidaDf['Valor crítico (%s)' % key] = value

print(salidaDf)
# Out:
# Resultados del Test de Dickey-Fuller para una diferenciación de la serie Gasolina Superior
# Estadístico de prueba       -7.800177e+00
# p-value                      7.529848e-12
# # de retardos usados         1.100000e+01
# # de observaciones usadas    2.760000e+02
# Valor crítico (1%)          -3.454267e+00
# Valor crítico (5%)          -2.872070e+00
# Valor crítico (10%)         -2.572381e+00
# dtype: float64

# %%
plt.plot(serie_diff)
plt.title("Serie diferenciada de Gasolina Superior")
plt.xlabel("Fecha")
plt.ylabel("Diferencia en Importacion")
plt.show()

# %% [markdown]
# Como ya han podido explorarlo, las redes neuronales (como LSTM) son sensibles a la escala de los datos. Si hay valores grandes, junto con pequeños, la red puede tener dificultades al aprender, especialmente usando funciones de activación como tanh o sigmoid. (Además que esto facilita el entrenamiento).
#
# Como las redes neuronales trabajan mejor con los datos normalizados, vamos a normalizar la serie.
#
# Al normalizarla, estamos haciendo que la data tenga una media de 0 y una desviación estándar de 1.

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
serie_diff_scaled = scaler.fit_transform(serie_diff.values.reshape(-1, 1))
serie_diff_scaled[:6]
# Out:
# array([[-0.00839873],
#        [-0.84051577],
#        [ 0.43027508],
#        [-0.18025785],
#        [ 0.09243469],
#        [ 0.19699376]])

# %% [markdown]
# Vamos a separar la serie en entrenamiento, validación y prueba. En este caso, tendremos 60% para entrenamiento y 20% para validación y prueba respectivamente.

# %%
# Largo total de la serie
total_len = len(serie_diff_scaled)

# Definir proporciones
train_prop = 0.6
val_prop = 0.2
test_prop = 0.2 

# Calcular índices
train_end = int(train_prop * total_len)
val_end = train_end + int(val_prop * total_len)

# Separar sin solapamientos
train = serie_diff_scaled[:train_end]
validation = serie_diff_scaled[train_end:val_end]
test = serie_diff_scaled[val_end:]

# Redimensionar para modelos tipo LSTM
train = train.reshape(-1, 1)
validation = validation.reshape(-1, 1)
test = test.reshape(-1, 1)

# Verificar tamaños
print(f"Total registros: {total_len}")
print(f"Train: {len(train)} | Validation: {len(validation)} | Test: {len(test)}")
# Out:
# Total registros: 288
# Train: 172 | Validation: 57 | Test: 59

# %%
train, type(train)
# Out:
# (array([[-0.00839873],
#         [-0.84051577],
#         [ 0.43027508],
#         [-0.18025785],
#         [ 0.09243469],
#         [ 0.19699376],
#         [-0.88675546],
#         [ 0.456268  ],
#         [ 0.24774682],
#         [-0.02961474],
#         [-0.31654349],
#         [ 0.12198815],
#         [-0.04442466],
#         [ 0.59040934],
#         [-0.76734717],
#         [ 0.39829577],
#         [ 0.32893891],
#         [-0.72807519],
#         [ 1.1279377 ],
#         [-0.83854206],
#         [ 0.19998117],
#         [ 0.12513508],
#         [-0.39540212],
#         [ 0.94208373],
#         [-0.10690206],
#         [ 0.11027309],
#         [-0.5202166 ],
#         [-0.18584341],
#         [ 0.77735496],
#         [-0.5586327 ],
#         [ 0.17240607],
#         [-0.69863262],
#         [ 0.6644721 ],
#         [-0.88565492],
#         [ 0.84189738],
#         [-0.6262373 ],
#         [ 0.44592695],
#         [-0.55738656],
#         [ 1.29496299],
#         [-0.46272333],
#         [-0.42405417],
#         [-0.25519219],
#         [-0.39960224],
#         [ 1.16702684],
#         [-0.09759059],
#         [-0.34960554],
#         [ 0.42284443],
#         [-0.01832377],
#         [-1.12287794],
#         [ 0.30183349],
#         [ 0.7879504 ],
#         [ 0.64168988],
#         [-0.99732584],
#         [ 1.00117106],
#         [-1.11464762],
#         [ 1.28363775],
#         [-2.3808626 ],
#         [ 2.12409708],
#         [-1.15407963],
#         [ 0.0686576 ],
#         [ 2.22367412],
#         [-2.86762041],
#         [ 0.91922845],
#         [ 0.0757552 ],
#         [-0.70319902],
#         [ 0.51291169],
#         [-0.12325143],
#         [-0.40657705],
#         [ 1.34142522],
#         [-1.53511985],
#         [ 0.90136862],
#         [-0.22113426],
#         [ 0.80925549],
#         [-0.78330468],
#         [ 0.88151156],
#         [-2.15986699],
#         [ 2.16703857],
#         [-0.66997179],
#         [ 0.0529162 ],
#         [ 0.31370458],
#         [-1.06207751],
#         [ 0.24756326],
#         [ 0.85741599],
#         [ 0.18467753],
#         [-2.15829111],
#         [ 2.15562705],
#         [-0.89490045],
#         [ 1.03780305],
#         [-0.93225969],
#         [-0.97202424],
#         [ 0.69832224],
#         [-0.915513  ],
#         [ 1.14474302],
#         [-0.6027759 ],
#         [ 0.35149332],
#         [ 0.45310778],
#         [-0.49574812],
#         [ 0.88505823],
#         [ 0.65164797],
#         [-1.77829065],
#         [-0.05015423],
#         [ 1.56613077],
#         [-1.61171712],
#         [ 0.87763477],
#         [-0.99262649],
#         [ 2.01221214],
#         [-2.02817992],
#         [ 0.71361863],
#         [-0.7489167 ],
#         [ 1.09476833],
#         [-1.2081265 ],
#         [ 1.6398594 ],
#         [-0.85573605],
#         [ 0.21147713],
#         [-0.05749942],
#         [ 0.11320664],
#         [-0.99124771],
#         [ 1.08940773],
#         [-1.61531834],
#         [ 2.60576579],
#         [-1.66288855],
#         [ 0.28262878],
#         [ 0.04342569],
#         [-0.57154902],
#         [ 0.47284423],
#         [-0.50709326],
#         [ 0.08754548],
#         [-0.63741274],
#         [ 0.40512964],
#         [ 0.09175474],
#         [ 0.61888387],
#         [ 0.53022134],
#         [-0.64598195],
#         [-0.40104783],
#         [-0.12750475],
#         [ 0.2811594 ],
#         [-0.13028456],
#         [ 1.07152686],
#         [-1.78151299],
#         [ 0.56255562],
#         [ 0.06587843],
#         [ 1.43558042],
#         [-1.53612025],
#         [ 0.36807476],
#         [ 0.08631008],
#         [ 0.22405283],
#         [-0.26596853],
#         [-0.00658658],
#         [ 0.64090451],
#         [-1.58740644],
#         [ 1.27619471],
#         [-0.89224654],
#         [ 0.15842284],
#         [-0.01066848],
#         [ 0.77419105],
#         [-0.88093611],
#         [ 0.61830324],
#         [-0.01882238],
#         [ 0.79812004],
#         [-1.99388083],
#         [ 1.8546679 ],
#         [-1.01754958],
#         [ 0.96949275],
#         [-1.02469424],
#         [ 0.93848301],
#         [-1.07603181],
#         [ 0.97046219],
#         [ 0.30669606],
#         [-0.71484821],
#         [ 1.21455519],
#         [-0.27183677],
#         [-0.15670107]]),
#  numpy.ndarray)

# %%
from operator import concat


def supervisada(serie,retrasos = 1):
    serie_x = []
    serie_y = []
    for i in range(len(serie)-retrasos):
        valor = serie[i:(i+retrasos),0]
        valor_sig = serie[i+retrasos,0]
        serie_x.append(valor)
        serie_y.append(valor_sig)
    return np.array(serie_x), np.array(serie_y)

x_train,y_train = supervisada(train)
x_val,y_val = supervisada(validation)
x_test,y_test = supervisada(test)

# %%
x_train
# Out:
# array([[-0.00839873],
#        [-0.84051577],
#        [ 0.43027508],
#        [-0.18025785],
#        [ 0.09243469],
#        [ 0.19699376],
#        [-0.88675546],
#        [ 0.456268  ],
#        [ 0.24774682],
#        [-0.02961474],
#        [-0.31654349],
#        [ 0.12198815],
#        [-0.04442466],
#        [ 0.59040934],
#        [-0.76734717],
#        [ 0.39829577],
#        [ 0.32893891],
#        [-0.72807519],
#        [ 1.1279377 ],
#        [-0.83854206],
#        [ 0.19998117],
#        [ 0.12513508],
#        [-0.39540212],
#        [ 0.94208373],
#        [-0.10690206],
#        [ 0.11027309],
#        [-0.5202166 ],
#        [-0.18584341],
#        [ 0.77735496],
#        [-0.5586327 ],
#        [ 0.17240607],
#        [-0.69863262],
#        [ 0.6644721 ],
#        [-0.88565492],
#        [ 0.84189738],
#        [-0.6262373 ],
#        [ 0.44592695],
#        [-0.55738656],
#        [ 1.29496299],
#        [-0.46272333],
#        [-0.42405417],
#        [-0.25519219],
#        [-0.39960224],
#        [ 1.16702684],
#        [-0.09759059],
#        [-0.34960554],
#        [ 0.42284443],
#        [-0.01832377],
#        [-1.12287794],
#        [ 0.30183349],
#        [ 0.7879504 ],
#        [ 0.64168988],
#        [-0.99732584],
#        [ 1.00117106],
#        [-1.11464762],
#        [ 1.28363775],
#        [-2.3808626 ],
#        [ 2.12409708],
#        [-1.15407963],
#        [ 0.0686576 ],
#        [ 2.22367412],
#        [-2.86762041],
#        [ 0.91922845],
#        [ 0.0757552 ],
#        [-0.70319902],
#        [ 0.51291169],
#        [-0.12325143],
#        [-0.40657705],
#        [ 1.34142522],
#        [-1.53511985],
#        [ 0.90136862],
#        [-0.22113426],
#        [ 0.80925549],
#        [-0.78330468],
#        [ 0.88151156],
#        [-2.15986699],
#        [ 2.16703857],
#        [-0.66997179],
#        [ 0.0529162 ],
#        [ 0.31370458],
#        [-1.06207751],
#        [ 0.24756326],
#        [ 0.85741599],
#        [ 0.18467753],
#        [-2.15829111],
#        [ 2.15562705],
#        [-0.89490045],
#        [ 1.03780305],
#        [-0.93225969],
#        [-0.97202424],
#        [ 0.69832224],
#        [-0.915513  ],
#        [ 1.14474302],
#        [-0.6027759 ],
#        [ 0.35149332],
#        [ 0.45310778],
#        [-0.49574812],
#        [ 0.88505823],
#        [ 0.65164797],
#        [-1.77829065],
#        [-0.05015423],
#        [ 1.56613077],
#        [-1.61171712],
#        [ 0.87763477],
#        [-0.99262649],
#        [ 2.01221214],
#        [-2.02817992],
#        [ 0.71361863],
#        [-0.7489167 ],
#        [ 1.09476833],
#        [-1.2081265 ],
#        [ 1.6398594 ],
#        [-0.85573605],
#        [ 0.21147713],
#        [-0.05749942],
#        [ 0.11320664],
#        [-0.99124771],
#        [ 1.08940773],
#        [-1.61531834],
#        [ 2.60576579],
#        [-1.66288855],
#        [ 0.28262878],
#        [ 0.04342569],
#        [-0.57154902],
#        [ 0.47284423],
#        [-0.50709326],
#        [ 0.08754548],
#        [-0.63741274],
#        [ 0.40512964],
#        [ 0.09175474],
#        [ 0.61888387],
#        [ 0.53022134],
#        [-0.64598195],
#        [-0.40104783],
#        [-0.12750475],
#        [ 0.2811594 ],
#        [-0.13028456],
#        [ 1.07152686],
#        [-1.78151299],
#        [ 0.56255562],
#        [ 0.06587843],
#        [ 1.43558042],
#        [-1.53612025],
#        [ 0.36807476],
#        [ 0.08631008],
#        [ 0.22405283],
#        [-0.26596853],
#        [-0.00658658],
#        [ 0.64090451],
#        [-1.58740644],
#        [ 1.27619471],
#        [-0.89224654],
#        [ 0.15842284],
#        [-0.01066848],
#        [ 0.77419105],
#        [-0.88093611],
#        [ 0.61830324],
#        [-0.01882238],
#        [ 0.79812004],
#        [-1.99388083],
#        [ 1.8546679 ],
#        [-1.01754958],
#        [ 0.96949275],
#        [-1.02469424],
#        [ 0.93848301],
#        [-1.07603181],
#        [ 0.97046219],
#        [ 0.30669606],
#        [-0.71484821],
#        [ 1.21455519],
#        [-0.27183677]])

# %%
y_train, type(y_train)
# Out:
# (array([-0.84051577,  0.43027508, -0.18025785,  0.09243469,  0.19699376,
#         -0.88675546,  0.456268  ,  0.24774682, -0.02961474, -0.31654349,
#          0.12198815, -0.04442466,  0.59040934, -0.76734717,  0.39829577,
#          0.32893891, -0.72807519,  1.1279377 , -0.83854206,  0.19998117,
#          0.12513508, -0.39540212,  0.94208373, -0.10690206,  0.11027309,
#         -0.5202166 , -0.18584341,  0.77735496, -0.5586327 ,  0.17240607,
#         -0.69863262,  0.6644721 , -0.88565492,  0.84189738, -0.6262373 ,
#          0.44592695, -0.55738656,  1.29496299, -0.46272333, -0.42405417,
#         -0.25519219, -0.39960224,  1.16702684, -0.09759059, -0.34960554,
#          0.42284443, -0.01832377, -1.12287794,  0.30183349,  0.7879504 ,
#          0.64168988, -0.99732584,  1.00117106, -1.11464762,  1.28363775,
#         -2.3808626 ,  2.12409708, -1.15407963,  0.0686576 ,  2.22367412,
#         -2.86762041,  0.91922845,  0.0757552 , -0.70319902,  0.51291169,
#         -0.12325143, -0.40657705,  1.34142522, -1.53511985,  0.90136862,
#         -0.22113426,  0.80925549, -0.78330468,  0.88151156, -2.15986699,
#          2.16703857, -0.66997179,  0.0529162 ,  0.31370458, -1.06207751,
#          0.24756326,  0.85741599,  0.18467753, -2.15829111,  2.15562705,
#         -0.89490045,  1.03780305, -0.93225969, -0.97202424,  0.69832224,
#         -0.915513  ,  1.14474302, -0.6027759 ,  0.35149332,  0.45310778,
#         -0.49574812,  0.88505823,  0.65164797, -1.77829065, -0.05015423,
#          1.56613077, -1.61171712,  0.87763477, -0.99262649,  2.01221214,
#         -2.02817992,  0.71361863, -0.7489167 ,  1.09476833, -1.2081265 ,
#          1.6398594 , -0.85573605,  0.21147713, -0.05749942,  0.11320664,
#         -0.99124771,  1.08940773, -1.61531834,  2.60576579, -1.66288855,
#          0.28262878,  0.04342569, -0.57154902,  0.47284423, -0.50709326,
#          0.08754548, -0.63741274,  0.40512964,  0.09175474,  0.61888387,
#          0.53022134, -0.64598195, -0.40104783, -0.12750475,  0.2811594 ,
#         -0.13028456,  1.07152686, -1.78151299,  0.56255562,  0.06587843,
#          1.43558042, -1.53612025,  0.36807476,  0.08631008,  0.22405283,
#         -0.26596853, -0.00658658,  0.64090451, -1.58740644,  1.27619471,
#         -0.89224654,  0.15842284, -0.01066848,  0.77419105, -0.88093611,
#          0.61830324, -0.01882238,  0.79812004, -1.99388083,  1.8546679 ,
#         -1.01754958,  0.96949275, -1.02469424,  0.93848301, -1.07603181,
#          0.97046219,  0.30669606, -0.71484821,  1.21455519, -0.27183677,
#         -0.15670107]),
#  numpy.ndarray)

# %%
(x_train.shape[0],1,1)
# Out:
# (171, 1, 1)

# %%
x_train = np.reshape(x_train,(x_train.shape[0],1,1))
x_val = np.reshape(x_val, (x_val.shape[0],1,1))
x_test = np.reshape(x_test, (x_test.shape[0],1,1))
len(x_val)
# Out:
# 56

# %% [markdown]
# ### Creamos el modelo.
# Vamos a utilizar solo una capa lstm

# %% [markdown]
# LSTM(units, input_shape=(pasos, características), stateful=False)
# - units: cantidad de neuronas. Cada una es como una "mini-memoria" que puede aprender patrones en secuencias.
# - input_shape: pasos (lags) y features (cant de variables)
# - batch_input_shape: Solo se usa si stateful=True. Igual que input_shape, pero le agregas el tamaño fijo del batch (batch_size). O sea: (batch_size, pasos, características).
# - stateful: mantiene el estado (memoria) entre batches, ayuda para entender dependencias a largo plazo entre batches
#
# Dense(1)
# #
# - Toma lo que sale de la LSTM y le aplica una transformación lineal con pesos y bias.
# - En este caso, Dense(1) significa: produce una sola salida (por ejemplo, una predicción de un número, como el siguiente valor de la serie).

# %%
unidades =  10
paso = 1 # lags, 1 lag es un mes. 
caracteristicas = 1 # es univariada
lote = 1


modelo1 = Sequential()
modelo1.add(LSTM(
    units=unidades, 
    input_shape=(paso, caracteristicas), 
    stateful=False  # desactivamos estado entre batches
))

# modelo1.add(LSTM(
#     units=unidades, 
#     batch_input_shape=(lote, paso, caracteristicas), 
#     stateful=True  # activamos estado entre batches
# ))
modelo1.add(Dense(1))
modelo1.summary()
# Out:
# C:\Users\jemil\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 10)             │           480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 491 (1.92 KB)
#  Trainable params: 491 (1.92 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Compilamos el modelo. Las métricas que nos van a servir para saber como funciona el modelo en términos de la pérdida es el error medio cuadrado.

# %%
modelo1.compile(loss='mean_squared_error',optimizer="rmsprop")

# %% [markdown]
# Vamos a entrenar el modelo. Para eso configuramos las epochs(épocas) que es la cantidad de iteraciones. Lo pondremos en 50.

# %%
epocas = 50
history= modelo1.fit(
    x = x_train,
    y = y_train,
    batch_size = lote,
    epochs = epocas,
    shuffle = False,
    validation_data = (x_val,y_val),
    verbose=1
)
# Out:
# Epoch 1/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.7099 - val_loss: 1.0965
# Epoch 2/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.6126 - val_loss: 0.9235
# Epoch 3/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5316 - val_loss: 0.7719
# Epoch 4/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4661 - val_loss: 0.6580
# Epoch 5/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4234 - val_loss: 0.5888
# Epoch 6/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4021 - val_loss: 0.5539
# Epoch 7/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3941 - val_loss: 0.5381
# Epoch 8/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3919 - val_loss: 0.5309
# Epoch 9/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3917 - val_loss: 0.5275
# Epoch 10/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3920 - val_loss: 0.5258
# Epoch 11/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3922 - val_loss: 0.5248
# Epoch 12/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3924 - val_loss: 0.5242
# Epoch 13/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3924 - val_loss: 0.5238
# Epoch 14/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3925 - val_loss: 0.5235
# Epoch 15/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3924 - val_loss: 0.5232
# Epoch 16/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3924 - val_loss: 0.5230
# Epoch 17/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3924 - val_loss: 0.5228
# Epoch 18/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3923 - val_loss: 0.5227
# Epoch 19/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3922 - val_loss: 0.5225
# Epoch 20/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3922 - val_loss: 0.5224
# Epoch 21/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3921 - val_loss: 0.5222
# Epoch 22/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3921 - val_loss: 0.5221
# Epoch 23/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3920 - val_loss: 0.5220
# Epoch 24/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3919 - val_loss: 0.5219
# Epoch 25/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3919 - val_loss: 0.5218
# Epoch 26/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3918 - val_loss: 0.5217
# Epoch 27/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3918 - val_loss: 0.5216
# Epoch 28/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3917 - val_loss: 0.5215
# Epoch 29/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3917 - val_loss: 0.5214
# Epoch 30/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3916 - val_loss: 0.5213
# Epoch 31/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3916 - val_loss: 0.5212
# Epoch 32/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3915 - val_loss: 0.5211
# Epoch 33/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3914 - val_loss: 0.5210
# Epoch 34/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3914 - val_loss: 0.5209
# Epoch 35/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3913 - val_loss: 0.5209
# Epoch 36/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3913 - val_loss: 0.5208
# Epoch 37/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3912 - val_loss: 0.5207
# Epoch 38/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3912 - val_loss: 0.5206
# Epoch 39/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3911 - val_loss: 0.5206
# Epoch 40/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3911 - val_loss: 0.5205
# Epoch 41/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3911 - val_loss: 0.5204
# Epoch 42/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3910 - val_loss: 0.5204
# Epoch 43/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3910 - val_loss: 0.5203
# Epoch 44/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3909 - val_loss: 0.5203
# Epoch 45/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3909 - val_loss: 0.5202
# Epoch 46/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3908 - val_loss: 0.5201
# Epoch 47/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3908 - val_loss: 0.5201
# Epoch 48/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3907 - val_loss: 0.5200
# Epoch 49/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3907 - val_loss: 0.5200
# Epoch 50/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3907 - val_loss: 0.5199

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='center')

# %% [markdown]
# Evaluemos ahora el modelo según la pérdida en cada uno de los conjuntos de datos.

# %%
print("Pérdida en Train")
modelo1.evaluate(
    x = x_train,
    y = y_train
)
print("Pérdida en Validación")
modelo1.evaluate(
    x = x_val,
    y = y_val
)
print("Pérdida en Test")
modelo1.evaluate(
    x = x_test,
    y = y_test
)
# Out:
# Pérdida en Train
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4232
# Pérdida en Validación
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.5521
# Pérdida en Test
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.1277
# 0.9300979375839233

# %% [markdown]
# Ahora vamos a predecir con el modelo 1.

# %%
prediccion_val = []

def prediccion_fun(data,modelo, batch_size,scaler,dif=False,dif_cant=1, Series = None , n=1):
    prediccion = [0]* (len(data))
    i=0
    for X in data:
        # X = np.reshape(X,(1,1,1))
        X = np.reshape(X, (1,) + X.shape)
        yhat = modelo1.predict(X, batch_size=batch_size,verbose=0)
        # invert scaling
        yhat = scaler.inverse_transform(yhat)
        if dif:
             # invert differencing
            yhat  = yhat + Series[(n+dif_cant*i)]
        # store
        prediccion[i]=yhat[0][0]
        i = i+1
    return prediccion


prediccion_val1 = prediccion_fun(x_val,modelo1, 1,scaler,dif=True,dif_cant=1, Series = serie.values , n=train_end)
prediccion_test1 = prediccion_fun(x_test,modelo1, 1,scaler,dif=True,dif_cant=1, Series = serie.values , n = len(serie.values) - len(x_test))

# %%
# df_val = pd.DataFrame(prediccion_val,index=serie[(train_prop):train_prop+val_prop].index) 
# df_test = pd.DataFrame(prediccion_test,index=serie[train_prop+len(df_val):len(serie)].index)
df_val = pd.DataFrame(prediccion_val1, index=serie[train_end+1:val_end].index)
df_test = pd.DataFrame(prediccion_test1, index=serie[val_end:].index[:len(prediccion_test1)])


plt.figure(figsize=(12,6))
plt.plot(serie, label='Serie original')
plt.plot(df_val, label='Predicción validación')
plt.plot(df_test, label='Predicción prueba')
plt.legend()
plt.title('Predicción de Importacion de gasolina superior')
plt.xlabel('Fecha')
plt.ylabel('Importacion')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Modelo 2

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

unidades = 50
paso = 12
caracteristicas = 1

modelo2 = Sequential()
modelo2.add(LSTM(
    units=unidades, 
    return_sequences=True,  # Necesario para apilar otra capa LSTM
    input_shape=(paso, caracteristicas),
    stateful=False
))
modelo2.add(Dropout(0.2))  # Regularización

modelo2.add(LSTM(
    units=25,
    stateful=False
))
modelo2.add(Dense(1))  # Capa de salida
modelo2.summary()
# Out:
# C:\Users\jemil\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_1 (LSTM)                   │ (None, 12, 50)         │        10,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 12, 50)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 25)             │         7,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            26 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 18,026 (70.41 KB)
#  Trainable params: 18,026 (70.41 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
modelo2.compile(loss='mean_squared_error',optimizer="rmsprop")

# %%
epocas = 50
history= modelo2.fit(
    x = x_train,
    y = y_train,
    batch_size = lote,
    epochs = epocas,
    shuffle = False,
    validation_data = (x_val,y_val),
    verbose=1
)
# Out:
# Epoch 1/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.6249 - val_loss: 0.7081
# Epoch 2/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4143 - val_loss: 0.5237
# Epoch 3/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3967 - val_loss: 0.5154
# Epoch 4/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3896 - val_loss: 0.5132
# Epoch 5/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3966 - val_loss: 0.5155
# Epoch 6/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3941 - val_loss: 0.5149
# Epoch 7/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3990 - val_loss: 0.5142
# Epoch 8/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3948 - val_loss: 0.5135
# Epoch 9/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3980 - val_loss: 0.5144
# Epoch 10/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4011 - val_loss: 0.5137
# Epoch 11/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3980 - val_loss: 0.5138
# Epoch 12/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3952 - val_loss: 0.5136
# Epoch 13/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3949 - val_loss: 0.5145
# Epoch 14/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3953 - val_loss: 0.5141
# Epoch 15/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4008 - val_loss: 0.5146
# Epoch 16/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3949 - val_loss: 0.5142
# Epoch 17/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3923 - val_loss: 0.5150
# Epoch 18/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4019 - val_loss: 0.5142
# Epoch 19/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3919 - val_loss: 0.5139
# Epoch 20/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4000 - val_loss: 0.5143
# Epoch 21/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3985 - val_loss: 0.5142
# Epoch 22/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4015 - val_loss: 0.5151
# Epoch 23/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3963 - val_loss: 0.5144
# Epoch 24/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4054 - val_loss: 0.5141
# Epoch 25/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3929 - val_loss: 0.5141
# Epoch 26/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3897 - val_loss: 0.5147
# Epoch 27/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3954 - val_loss: 0.5152
# Epoch 28/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3951 - val_loss: 0.5156
# Epoch 29/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3879 - val_loss: 0.5155
# Epoch 30/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3945 - val_loss: 0.5149
# Epoch 31/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3939 - val_loss: 0.5150
# Epoch 32/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3877 - val_loss: 0.5131
# Epoch 33/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4007 - val_loss: 0.5151
# Epoch 34/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3957 - val_loss: 0.5146
# Epoch 35/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4029 - val_loss: 0.5146
# Epoch 36/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3953 - val_loss: 0.5149
# Epoch 37/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3949 - val_loss: 0.5148
# Epoch 38/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4013 - val_loss: 0.5143
# Epoch 39/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3886 - val_loss: 0.5144
# Epoch 40/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3920 - val_loss: 0.5136
# Epoch 41/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3919 - val_loss: 0.5147
# Epoch 42/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3950 - val_loss: 0.5158
# Epoch 43/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3998 - val_loss: 0.5149
# Epoch 44/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3836 - val_loss: 0.5137
# Epoch 45/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3944 - val_loss: 0.5155
# Epoch 46/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3980 - val_loss: 0.5151
# Epoch 47/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3993 - val_loss: 0.5151
# Epoch 48/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3968 - val_loss: 0.5146
# Epoch 49/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4049 - val_loss: 0.5143
# Epoch 50/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3926 - val_loss: 0.5146

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='center')

# %%
print("Pérdida en Train")
modelo2.evaluate(
    x = x_train,
    y = y_train
)
print("Pérdida en Validación")
modelo2.evaluate(
    x = x_val,
    y = y_val
)
print("Pérdida en Test")
modelo2.evaluate(
    x = x_test,
    y = y_test
)
# Out:
# Pérdida en Train
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4210
# Pérdida en Validación
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.5430
# Pérdida en Test
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.1548
# 0.9503177404403687

# %%
prediccion_val = []

def prediccion_fun(data,modelo, batch_size,scaler,dif=False,dif_cant=1, Series = None , n=1):
    prediccion = [0]* (len(data))
    i=0
    for X in data:
        # X = np.reshape(X,(1,1,1))
        X = np.reshape(X, (1,) + X.shape)
        yhat = modelo2.predict(X, batch_size=batch_size,verbose=0)
        # invert scaling
        yhat = scaler.inverse_transform(yhat)
        if dif:
             # invert differencing
            yhat  = yhat + Series[(n+dif_cant*i)]
        # store
        prediccion[i]=yhat[0][0]
        i = i+1
    return prediccion


prediccion_val2 = prediccion_fun(x_val,modelo2, 1,scaler,dif=True,dif_cant=1, Series = serie.values , n=train_end)
prediccion_test2 = prediccion_fun(x_test,modelo2, 1,scaler,dif=True,dif_cant=1, Series = serie.values , n = len(serie.values) - len(x_test))

# %%
# df_val = pd.DataFrame(prediccion_val,index=serie[(train_prop):train_prop+val_prop].index) 
# df_test = pd.DataFrame(prediccion_test,index=serie[train_prop+len(df_val):len(serie)].index)
df_val = pd.DataFrame(prediccion_val2, index=serie[train_end+1:val_end].index)
df_test = pd.DataFrame(prediccion_test2, index=serie[val_end:].index[:len(prediccion_test2)])


plt.figure(figsize=(12,6))
plt.plot(serie, label='Serie original')
plt.plot(df_val, label='Predicción validación')
plt.plot(df_test, label='Predicción prueba')
plt.legend()
plt.title('Predicción de Importacion de gasolina superior')
plt.xlabel('Fecha')
plt.ylabel('Importacion')
plt.grid(True)
plt.show()

# %%
# --- Modelo 1 ---
rmse_val_1 = np.sqrt(mean_squared_error(y_val, prediccion_val1))
rmse_test_1 = np.sqrt(mean_squared_error(y_test, prediccion_test1))

# --- Modelo 2 ---
rmse_val_2 = np.sqrt(mean_squared_error(y_val, prediccion_val2))
rmse_test_2 = np.sqrt(mean_squared_error(y_test, prediccion_test2))

# Mostrar resultados
print(f"Modelo 1 - RMSE validación: {rmse_val_1:.2f} | RMSE prueba: {rmse_test_1:.2f}")
print(f"Modelo 2 - RMSE validación: {rmse_val_2:.2f} | RMSE prueba: {rmse_test_2:.2f}")
# Out:
# Modelo 1 - RMSE validación: 610234.91 | RMSE prueba: 657520.30
# Modelo 2 - RMSE validación: 613035.98 | RMSE prueba: 661198.36
